# %% [markdown]
# # Log Analysis with CountVectorizer for SteelHead messages

# %%
import pandas as pd

# %%
df = pd.read_csv("../input/sh_msg.txt",sep='|',index_col=0, parse_dates=True,
                 header=None,names=['timestamp','process','func_level','log_entry'])

# %%
pd.options.display.max_colwidth = 100 # controls max display

df.head()
# Out:
#                               process               func_level  \
# timestamp
# 2019-05-07 00:00:16        rsyslogd:                  [origin
# 2019-05-07 00:00:16           admin:      BUILD_PROD_VERSION:
# 2019-05-07 00:00:16    sport[31079]:      [splice/probe.INFO]
# 2019-05-07 00:00:16    sport[31079]:      [splice/probe.INFO]
# 2019-05-07 00:00:16    sport[31079]:     [splice/server.INFO]
#
#                                                                                                                log_entry
# timestamp
# 2019-05-07 00:00:16             software="rsyslogd" swVersion="" xpid="" xinfo="http//wwwrsyslogcom"] rsyslogd was HUPed
# 2019-05-07 00:00:16                                                                      rbt_sh # x_ uuiddeebcedfdeaeebf
# 2019-05-07 00:00:16                                                                                  locl clnt serv init
# ...

# %%
# remove numbers and special characters from process and log_entry
import re

df.process = df.process.apply(lambda x: re.sub('[0-9:\[\]]+', '', x))

# %%
# get frequency count of process
df.process.value_counts()
# Out:
#   sport                                                                         1294379
#   rscored                                                                          4536
#                                                                                    4081
#   mgmtd                                                                            3040
#   batch                                                                            1047
#   mdreq                                                                            1034
#   kernelintercept.INFO                                                              870
#   periodic_raidcheck                                                                638
#   AUTO-INIT                                                                         438
#   lumberjack_rbt                                                                    388
#   rstild                                                                            271
# ...

# %%
# check for non INFO logs as well as any specific string within log entry
df = df[df.func_level.str.contains("ERR")]

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
% matplotlib inline

def plot_world_cloud (text):
    # Create stopword list:
    #stopwords = set(STOPWORDS)

    # Create and generate a word cloud image:
    #wordcloud = WordCloud(width=500, height=350, stopwords=stopwords, max_words=100, background_color="white").generate(text)
    wordcloud = WordCloud(width=600, height=350, max_words=100, background_color="white").generate(text)

    # Display the generated image:
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# get all log entries
text = " ".join(entry for entry in df.log_entry)
plot_world_cloud(text)

# %%
# get all log entries
text = " ".join(entry for entry in df.func_level)
plot_world_cloud(text)

# %% [markdown]
# ## Count Unigrams

# %%
from sklearn.feature_extraction.text import CountVectorizer

def get_top_n_words(corpus, n=None):
    vec = CountVectorizer(stop_words = 'english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_words(df['log_entry'], 20)
for word, freq in common_words:
    print(word, freq)
# Out:
# /Users/kselvadurai/anaconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning:
#
# numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#
# /Users/kselvadurai/anaconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning:
#
# numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#
# /Users/kselvadurai/anaconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning:
#
# numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#
# /Users/kselvadurai/anaconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning:
#
# numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
# connection 380
# error 335
# timed 282
# peer 251
# reading 250
# splice 220
# oob 171
# hdr 164
# info 164
# connecting 115
# err 107
# serv 94
# clnt 94
# closed 56
# reset 42
# connected 22
# transport 21
# endpoint 21
# writing 21
# sport 9

# %% [markdown]
# ## Bigrams

# %%
def get_top_n_bigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 2)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_bigram(df['log_entry'], 20)
for word, freq in common_words:
    print(word, freq)
# Out:
# timed out 282
# connection timed 282
# hdr info 164
# error reading 164
# reading splice 164
# info connection 164
# from error 164
# splice hdr 164
# error connecting 115
# connecting to 115
# peer oob 115
# to peer 115
# err while 107
# serv error 94
# peer serv 94
# clnt peer 94
# while reading 86
# reading connection 83
# with error 56
# error connection 56

# %% [markdown]
# ## Trigrams

# %%
def get_top_n_trigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(3, 3)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_trigram(df['log_entry'], 20)
for word, freq in common_words:
    print(word,"\t",freq)
# Out:
# connection timed out 	 282
# splice hdr info 	 164
# from error reading 	 164
# error reading splice 	 164
# reading splice hdr 	 164
# hdr info connection 	 164
# info connection timed 	 144
# error connecting to 	 115
# to peer oob 	 115
# connecting to peer 	 115
# clnt peer serv 	 94
# peer serv error 	 94
# serv error connecting 	 94
# err while reading 	 86
# while reading connection 	 83
# reading connection timed 	 76
# closed with error 	 56
# connection closed with 	 56
# oob splice connection 	 56
# splice connection closed 	 56
